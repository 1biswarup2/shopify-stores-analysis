# %%
# !git clone https://github.com/TeamDukaan/performance.git
# Out:
# Cloning into 'performance'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), 69.69 KiB | 2.18 MiB/s, done.

# %%
import pandas as pd
df=pd.read_csv('performance/shopify stores - shopify.csv')

# %%
df
# Out:
#                                  URL
# 0             https://www.shopify.in
# 1     https://www.boat-lifestyle.com
# 2            https://hammeronline.in
# 3            https://www.gonoise.com
# 4              https://www.buywow.in
# ...                              ...
# 9757      https://alicecosmetics.net
# 9758             https://eyantra.net
# 9759         https://zeeayurveda.net
# 9760   https://geneticnutrition.site
# 9761        https://www.thesirona.us
#
# [9762 rows x 1 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df.head(1000)

# %%
df_array=df1.to_numpy()

# %%
df_array
# Out:
# array([['https://www.shopify.in'],
#        ['https://www.boat-lifestyle.com'],
#        ['https://hammeronline.in'],
#        ['https://www.gonoise.com'],
#        ['https://www.buywow.in'],
#        ['https://bummer.in'],
#        ['https://www.urbanmonkey.com'],
#        ['https://www.oberlo.in'],
#        ['https://store.cashify.in'],
#        ['https://linkpop.com'],
#        ['https://byjus.com'],
#        ['https://nurserylive.com'],
#        ['https://frenchcrown.in'],
#        ['https://www.bunaai.com'],
#        ['https://www.headphonezone.in'],
#        ['https://www.nicobar.com'],
#        ['https://gourmetgarden.in'],
#        ['https://www.giva.co'],
#        ['https://support.boat-lifestyle.com'],
#        ['https://www.fabbox.in'],
#        ['https://neemans.com'],
#        ['https://www.cashify.in'],
#        ['https://skinkraft.com'],
#        ['https://fullyfilmy.in'],
#        ['https://www.mcaffeine.com'],
#        ['https://thejodilife.com'],
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
site=df_array[0]
print(site[0])
var=requests.get(site[0]).text
soup=BeautifulSoup(var,'lxml')
# Out:
# https://www.shopify.in

# %%
f=open("titles.txt","w")
for site in df_array:
  try:
    html_text=requests.get(site[0]).text
    soup=BeautifulSoup(html_text,'lxml')
    header=soup.find('head').title.text
    f.write(header)
    print(header)
  except:
    continue
# Out:
# Start and grow your e-commerce business - 3-Day Free Trial - Shopify India
#
#       Buy Earbuds, Headphones, Earphones at India’s No.1 Earwear Brand: boAt
#
# Bluetooth Calling Smartwatch | Wireless Earbuds | Headphones
# – Hammer
#
#
#   Noise | India's No.1 Wearable Watch Brand
#
#
#
#
# Wow Skin Science India
# Bummer | Soft Most Comfortable Underwear & Loungewear For Men & Women
#
# Urban Monkey® | Streetwear Clothing Brand
# Oberlo | Where Self Made is Made
# Buy Refurbished Mobile Phone online in India at best price | cashify.in
# Linkpop by Shopify: the link in bio tool for commerce in 2023
# 504 Gateway Time-out
# Buy Plants, Seeds, Pots, Garden Decor @ lowest price — Nurserylive
# FRENCH CROWN® India : Men and Women Premium Clothing Store
#
#     Traditional & Contemporary Clothing – Bunaai
#
# Headphone Zone: Rediscover Music at India's #1 Audiophile Store
#
#       Nicobar | Modern, mindful, India-rooted designs
#
# ...

# %%
titles
